# %%
import pandas as pd

pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
breads_cereals_and_other_grain_products_url = "https://raw.githubusercontent.com/yildiramdsa/nutrient_composition_of_common_foods_in_canada_analyzing_the_canadian_nutrient_file/main/data/raw/nutrient_value_breads_cereals_and_other_grain_products_2008_valeur_nutritive_pains_cereales_et_autres_produits_cerealiers-eng.csv"

try:
    breads_cereals_and_other_grain_products_df = pd.read_csv(breads_cereals_and_other_grain_products_url, encoding="utf-8", header=None)
except UnicodeDecodeError:
    breads_cereals_and_other_grain_products_df = pd.read_csv(breads_cereals_and_other_grain_products_url, encoding="latin1", header=None)

breads_cereals_and_other_grain_products_df.head()
# Out:
#                                                   0        1        2   \
# 0  Nutrient Value of Some Common Foods - 2008 Edi...      NaN      NaN
# 1           BREADS, CEREALS AND OTHER GRAIN PRODUCTS      NaN      NaN
# 2                                          Food name  Measure  Weight
# 3                                                NaN      NaN        g
# 4                                   FLOURS AND BRANS      NaN      NaN
#
#        3       4        5             6            7                    8   \
# 0     NaN     NaN      NaN           NaN          NaN                  NaN
# 1     NaN     NaN      NaN           NaN          NaN                  NaN
# 2  Energy  Energy  Protein  Carbohydrate  Total Sugar  Total Dietary Fibre
# 3    kcal      kJ        g             g            g                    g
# 4     NaN     NaN      NaN           NaN          NaN                  NaN
#
#           9              10           11       12    13      14         15  \
# ...

# %%
breads_cereals_and_other_grain_products_df = breads_cereals_and_other_grain_products_df.iloc[2:].reset_index(drop=True) # Drop the first two rows (row indices 0 and 1)
breads_cereals_and_other_grain_products_df.columns = breads_cereals_and_other_grain_products_df.iloc[0] # Assign first row as column names
breads_cereals_and_other_grain_products_df = breads_cereals_and_other_grain_products_df[1:].reset_index(drop=True) # Remove the duplicate header row
breads_cereals_and_other_grain_products_df.head()
# Out:
# 0         Food name Measure Weight  Energy Energy Protein Carbohydrate  \
# 0               NaN     NaN       g   kcal     kJ       g            g
# 1  FLOURS AND BRANS     NaN     NaN    NaN    NaN     NaN          NaN
# 2    Chickpea flour   125mL      49    188    786      11           28
# 3     Cornmeal, dry   125mL      73    267   1116       6           57
# 4     Oat bran, dry   125mL      50    122    511       9           33
#
# 0 Total Sugar Total Dietary Fibre Total Fat Saturated Fat Cholesterol Calcium  \
# 0           g                   g         g             g          mg      mg
# 1         NaN                 NaN       NaN           NaN         NaN     NaN
# 2           5                 5.2         3           0.3           0      22
# 3           1                 5.4         1           0.2           0       4
# 4           1                 5.2         3           0.7           0      29
#
# ...

# %%
breads_cereals_and_other_grain_products_df.columns = [
    'Food Name', 'Measure', 'Weight (g)', 'Energy (kcal)', 'Energy (kJ)',
    'Protein (g)', 'Carbohydrate (g)', 'Total Sugar (g)',
    'Total Dietary Fibre (g)', 'Total Fat (g)', 'Saturated Fat (g)',
    'Cholesterol (mg)', 'Calcium (mg)', 'Iron (mg)', 'Sodium (mg)',
    'Potassium (mg)', 'Magnesium (mg)', 'Phosphorus (mg)',
    'Thiamin (mg)', 'Riboflavin (mg)', 'Niacin (NE)', 'Folate (DFE)'
    ]

breads_cereals_and_other_grain_products_df = breads_cereals_and_other_grain_products_df.iloc[1:].reset_index(drop=True)

breads_cereals_and_other_grain_products_df['Food Category'] = 'Breads, Cereals and Other Grain Products'
breads_cereals_and_other_grain_products_df
# Out:
#                                              Food Name     Measure Weight (g)  \
# 0                                     FLOURS AND BRANS         NaN        NaN
# 1                                       Chickpea flour       125mL         49
# 2                                        Cornmeal, dry       125mL         73
# 3                                        Oat bran, dry       125mL         50
# 4                                      Oat flakes, dry       125mL         53
# 5                                         Potato flour       125mL         85
# 6                                           Rice flour       125mL         83
# 7                                     Rye flour, light       125mL         54
# 8                                            Soy flour       125mL         53
# 9                                           Wheat bran        15mL          4
# 10                            Wheat flour, all purpose       125mL         66
# ...

# %%
breads_cereals_and_other_grain_products_df.loc[1:14, 'Food Subcategory'] = "Flours and Brans"
breads_cereals_and_other_grain_products_df.loc[16:41, 'Food Subcategory'] = "Breads and Buns"
breads_cereals_and_other_grain_products_df.loc[43:49, 'Food Subcategory'] = "Other Bread Products"
breads_cereals_and_other_grain_products_df.loc[51:60, 'Food Subcategory'] = "Pancakes, Waffles and French Toast"
breads_cereals_and_other_grain_products_df.loc[62:80, 'Food Subcategory'] = "Rice, Pasta and Other Grains"
breads_cereals_and_other_grain_products_df.loc[82:126, 'Food Subcategory'] = "Breakfast Cereals"
breads_cereals_and_other_grain_products_df.loc[128:139, 'Food Subcategory'] = "Crackers"

breads_cereals_and_other_grain_products_df
# Out:
#                                              Food Name     Measure Weight (g)  \
# 0                                     FLOURS AND BRANS         NaN        NaN
# 1                                       Chickpea flour       125mL         49
# 2                                        Cornmeal, dry       125mL         73
# 3                                        Oat bran, dry       125mL         50
# 4                                      Oat flakes, dry       125mL         53
# 5                                         Potato flour       125mL         85
# 6                                           Rice flour       125mL         83
# 7                                     Rye flour, light       125mL         54
# 8                                            Soy flour       125mL         53
# 9                                           Wheat bran        15mL          4
# 10                            Wheat flour, all purpose       125mL         66
# ...

# %%
breads_cereals_and_other_grain_products_df = breads_cereals_and_other_grain_products_df.drop(index=[0, 15, 42, 50, 61, 81, 127])
breads_cereals_and_other_grain_products_df = breads_cereals_and_other_grain_products_df.reset_index(drop=True)
breads_cereals_and_other_grain_products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Food Name                133 non-null    object
#  1   Measure                  133 non-null    object
#  2   Weight (g)               133 non-null    object
#  3   Energy (kcal)            133 non-null    object
#  4   Energy (kJ)              133 non-null    object
#  5   Protein (g)              133 non-null    object
#  6   Carbohydrate (g)         133 non-null    object
#  7   Total Sugar (g)          119 non-null    object
#  8   Total Dietary Fibre (g)  132 non-null    object
#  9   Total Fat (g)            133 non-null    object
#  10  Saturated Fat (g)        110 non-null    object
#  11  Cholesterol (mg)         132 non-null    object
#  12  Calcium (mg)             133 non-null    object
#  13  Iron (mg)                133 non-null    object
# ...

# %%
baked_goods_url = "https://raw.githubusercontent.com/yildiramdsa/nutrient_composition_of_common_foods_in_canada_analyzing_the_canadian_nutrient_file/main/data/raw/nutrient_value_baked_2008_valeur_nutritive_boulangerie-eng.csv"

try:
    baked_goods_df = pd.read_csv(baked_goods_url, encoding="utf-8", header=None)
except UnicodeDecodeError:
    baked_goods_df = pd.read_csv(baked_goods_url, encoding="latin1", header=None)

baked_goods_df.head()
# Out:
#                                                   0        1        2   \
# 0  Nutrient Value of Some Common Foods - 2008 Edi...      NaN      NaN
# 1                                        BAKED GOODS      NaN      NaN
# 2                                          Food name  Measure  Weight
# 3                  BISCUITS, CROISSANTS, AND MUFFINS      NaN      NaN
# 4            Biscuit, plain or buttermilk, fast food        1       51
#
#        3       4        5             6            7                    8   \
# 0     NaN     NaN      NaN           NaN          NaN                  NaN
# 1     NaN     NaN      NaN           NaN          NaN                  NaN
# 2  Energy  Energy  Protein  Carbohydrate  Total Sugar  Total Dietary Fibre
# 3     NaN     NaN      NaN           NaN          NaN                  NaN
# 4     186     776        3            25            2                  0.7
#
#           9              10           11       12    13      14         15  \
# ...

# %%
baked_goods_df = baked_goods_df.iloc[2:].reset_index(drop=True)
baked_goods_df.columns = baked_goods_df.iloc[0]
baked_goods_df = baked_goods_df[1:].reset_index(drop=True)
baked_goods_df.head()
# Out:
# 0                                      Food name Measure Weight  Energy  \
# 0              BISCUITS, CROISSANTS, AND MUFFINS     NaN     NaN    NaN
# 1        Biscuit, plain or buttermilk, fast food       1      51    186
# 2  Biscuit, plain or buttermilk, from mix, baked       1      30     97
# 3         Biscuit, plain or buttermilk, homemade       1      60    212
# 4      Biscuit, plain, refrigerated dough, baked       1      27     93
#
# 0 Energy Protein Carbohydrate Total Sugar Total Dietary Fibre Total Fat  \
# 0    NaN     NaN          NaN         NaN                 NaN       NaN
# 1    776       3           25           2                 0.7         8
# 2    404       2           14           3                 0.4         4
# 3    888       4           27           1                 0.9        10
# 4    391       2           13          tr                 0.4         4
#
# 0 Saturated Fat Cholesterol Calcium Iron Sodium Potassium Magnesium  \
# ...

# %%
baked_goods_df.columns = [
    'Food Name', 'Measure', 'Weight (g)', 'Energy (kcal)', 'Energy (kJ)',
    'Protein (g)', 'Carbohydrate (g)', 'Total Sugar (g)',
    'Total Dietary Fibre (g)', 'Total Fat (g)', 'Saturated Fat (g)',
    'Cholesterol (mg)', 'Calcium (mg)', 'Iron (mg)', 'Sodium (mg)',
    'Potassium (mg)', 'Magnesium (mg)', 'Phosphorus (mg)',
    'Thiamin (mg)', 'Riboflavin (mg)', 'Niacin (NE)', 'Folate (DFE)'
    ]

baked_goods_df['Food Category'] = 'Baked Goods'
baked_goods_df
# Out:
#                                             Food Name   Measure Weight (g)  \
# 0                   BISCUITS, CROISSANTS, AND MUFFINS       NaN        NaN
# 1             Biscuit, plain or buttermilk, fast food         1         51
# 2       Biscuit, plain or buttermilk, from mix, baked         1         30
# 3              Biscuit, plain or buttermilk, homemade         1         60
# 4           Biscuit, plain, refrigerated dough, baked         1         27
# 5                                   Croissant, butter         1         57
# 6               Muffin, blueberry, from mix, prepared         1         54
# 7                    Muffin, bran, from mix, prepared         1         55
# 8                              Muffin, bran, homemade         1         57
# 9                          Muffin, carrot, commercial         1        113
# 10                 Muffin, chocolate chip, commercial         1        113
# ...

# %%
baked_goods_df.loc[1:12, 'Food Subcategory'] = "Biscuits, Croissants and Muffins"
baked_goods_df.loc[14:42, 'Food Subcategory'] = "Cookies, Granola Bars and Other Bars"
baked_goods_df.loc[44:68, 'Food Subcategory'] = "Cakes"
baked_goods_df.loc[70:82, 'Food Subcategory'] = "Pies"
baked_goods_df.loc[84:96, 'Food Subcategory'] = "Other Baked Goods"

baked_goods_df
# Out:
#                                             Food Name   Measure Weight (g)  \
# 0                   BISCUITS, CROISSANTS, AND MUFFINS       NaN        NaN
# 1             Biscuit, plain or buttermilk, fast food         1         51
# 2       Biscuit, plain or buttermilk, from mix, baked         1         30
# 3              Biscuit, plain or buttermilk, homemade         1         60
# 4           Biscuit, plain, refrigerated dough, baked         1         27
# 5                                   Croissant, butter         1         57
# 6               Muffin, blueberry, from mix, prepared         1         54
# 7                    Muffin, bran, from mix, prepared         1         55
# 8                              Muffin, bran, homemade         1         57
# 9                          Muffin, carrot, commercial         1        113
# 10                 Muffin, chocolate chip, commercial         1        113
# ...

# %%
baked_goods_df = baked_goods_df.drop(index=[0, 13, 43, 69, 61, 83])
baked_goods_df = baked_goods_df.reset_index(drop=True)
baked_goods_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Food Name                91 non-null     object
#  1   Measure                  91 non-null     object
#  2   Weight (g)               91 non-null     object
#  3   Energy (kcal)            89 non-null     object
#  4   Energy (kJ)              89 non-null     object
#  5   Protein (g)              89 non-null     object
#  6   Carbohydrate (g)         89 non-null     object
#  7   Total Sugar (g)          65 non-null     object
#  8   Total Dietary Fibre (g)  89 non-null     object
#  9   Total Fat (g)            89 non-null     object
#  10  Saturated Fat (g)        89 non-null     object
#  11  Cholesterol (mg)         88 non-null     object
#  12  Calcium (mg)             89 non-null     object
#  13  Iron (mg)                89 non-null     object
# ...

# %%
vegetables_and_vegetable_products_url = "https://raw.githubusercontent.com/yildiramdsa/nutrient_composition_of_common_foods_in_canada_analyzing_the_canadian_nutrient_file/main/data/raw/nutrient_value_vegetables_and_vegetable_products_2008_valeur_nutritive_legumes_et_produits_base_de_legumes-eng.csv"

try:
    vegetables_and_vegetable_products_df = pd.read_csv(vegetables_and_vegetable_products_url, encoding="utf-8", header=None)
except UnicodeDecodeError:
    vegetables_and_vegetable_products_df = pd.read_csv(vegetables_and_vegetable_products_url, encoding="latin1", header=None)

vegetables_and_vegetable_products_df.head()
# Out:
#                                                   0        1        2   \
# 0  Nutrient Value of Some Common Foods - 2008 Edi...      NaN      NaN
# 1                  VEGETABLES AND VEGETABLE PRODUCTS      NaN      NaN
# 2                                          Food name  Measure  Weight
# 3                                                NaN      NaN        g
# 4                                         VEGETABLES      NaN      NaN
#
#        3       4        5             6            7                    8   \
# 0     NaN     NaN      NaN           NaN          NaN                  NaN
# 1     NaN     NaN      NaN           NaN          NaN                  NaN
# 2  Energy  Energy  Protein  Carbohydrate  Total Sugar  Total Dietary Fibre
# 3    kcal      kJ        g             g            g                    g
# 4     NaN     NaN      NaN           NaN          NaN                  NaN
#
#           9        10    11      12         13         14          15  \
# ...

# %%
vegetables_and_vegetable_products_df = vegetables_and_vegetable_products_df.iloc[2:].reset_index(drop=True)
vegetables_and_vegetable_products_df.columns = vegetables_and_vegetable_products_df.iloc[0]
vegetables_and_vegetable_products_df = vegetables_and_vegetable_products_df[1:].reset_index(drop=True)
vegetables_and_vegetable_products_df.head()
# Out:
# 0                           Food name  Measure Weight  Energy Energy Protein  \
# 0                                 NaN      NaN       g   kcal     kJ       g
# 1                          VEGETABLES      NaN     NaN    NaN    NaN     NaN
# 2                Alfalfa sprouts, raw     60mL       8      2     10      tr
# 3   Artichoke hearts, canned in water  1 heart      27     13     56       1
# 4  Artichoke hearts, marinated in oil  1 heart      28     27    111       1
#
# 0 Carbohydrate Total Sugar Total Dietary Fibre Total Fat Calcium Iron Sodium  \
# 0            g           g                   g         g      mg   mg     mg
# 1          NaN         NaN                 NaN       NaN     NaN  NaN    NaN
# 2           tr          tr                 0.2        tr       3  0.1      1
# 3            3          tr                   1        tr      12  0.3     74
# 4            3          tr                   1         2      12  0.3     79
#
# ...

# %%
vegetables_and_vegetable_products_df.columns = [
    'Food Name', 'Measure', 'Weight (g)', 'Energy (kcal)', 'Energy (kJ)',
    'Protein (g)', 'Carbohydrate (g)', 'Total Sugar (g)',
    'Total Dietary Fibre (g)', 'Total Fat (g)', 'Calcium (mg)',
    'Iron (mg)', 'Sodium (mg)', 'Potassium (mg)', 'Magnesium (mg)',
    'Phosphorus (mg)', 'Vitamin A (RAE)', 'Beta-carotene (mcg)', 'Lycopene (mcg)',
    'Folate (DFE)', 'Vitamin C (mg)', 'Vitamin B12 (mcg)'
    ]

vegetables_and_vegetable_products_df = vegetables_and_vegetable_products_df.iloc[1:].reset_index(drop=True)

vegetables_and_vegetable_products_df['Food Category'] = 'Vegetables and Vegetable Products'
vegetables_and_vegetable_products_df
# Out:
#                                              Food Name    Measure Weight (g)  \
# 0                                           VEGETABLES        NaN        NaN
# 1                                 Alfalfa sprouts, raw       60mL          8
# 2                    Artichoke hearts, canned in water    1 heart         27
# 3                   Artichoke hearts, marinated in oil    1 heart         28
# 4                           Artichoke, boiled, drained   1 medium        120
# 5                           Asparagus, canned, drained   6 spears        108
# 6          Asparagus, fresh or frozen, boiled, drained   6 spears         90
# 7                             Bean sprouts, stir-fried      125mL         66
# 8                 Beans, lima, frozen, boiled, drained      125mL         95
# 9    Beans, snap (green, yellow, Italian), canned, ...      125mL         71
# 10   Beans, snap (green, yellow, Italian), fresh or...      125mL         71
# ...

# %%
vegetables_and_vegetable_products_df.loc[1:104, 'Food Subcategory'] = "Vegetables"
vegetables_and_vegetable_products_df.loc[106:115, 'Food Subcategory'] = "Vegetable Juices and Other Products"

vegetables_and_vegetable_products_df
# Out:
#                                              Food Name    Measure Weight (g)  \
# 0                                           VEGETABLES        NaN        NaN
# 1                                 Alfalfa sprouts, raw       60mL          8
# 2                    Artichoke hearts, canned in water    1 heart         27
# 3                   Artichoke hearts, marinated in oil    1 heart         28
# 4                           Artichoke, boiled, drained   1 medium        120
# 5                           Asparagus, canned, drained   6 spears        108
# 6          Asparagus, fresh or frozen, boiled, drained   6 spears         90
# 7                             Bean sprouts, stir-fried      125mL         66
# 8                 Beans, lima, frozen, boiled, drained      125mL         95
# 9    Beans, snap (green, yellow, Italian), canned, ...      125mL         71
# 10   Beans, snap (green, yellow, Italian), fresh or...      125mL         71
# ...

# %%
vegetables_and_vegetable_products_df = vegetables_and_vegetable_products_df.drop(index=[0, 105])
vegetables_and_vegetable_products_df = vegetables_and_vegetable_products_df.reset_index(drop=True)
vegetables_and_vegetable_products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Food Name                114 non-null    object
#  1   Measure                  114 non-null    object
#  2   Weight (g)               114 non-null    object
#  3   Energy (kcal)            114 non-null    object
#  4   Energy (kJ)              114 non-null    object
#  5   Protein (g)              114 non-null    object
#  6   Carbohydrate (g)         114 non-null    object
#  7   Total Sugar (g)          95 non-null     object
#  8   Total Dietary Fibre (g)  113 non-null    object
#  9   Total Fat (g)            114 non-null    object
#  10  Calcium (mg)             114 non-null    object
#  11  Iron (mg)                114 non-null    object
#  12  Sodium (mg)              114 non-null    object
#  13  Potassium (mg)           114 non-null    object
# ...

# %%
fruit_and_fruit_juices_url = "https://raw.githubusercontent.com/yildiramdsa/nutrient_composition_of_common_foods_in_canada_analyzing_the_canadian_nutrient_file/main/data/raw/nutrient_value_fruits_and_fruit_juices_2008_valeur_nutritive_fruits_et_jus_de_fruits-eng.csv"

try:
    fruit_and_fruit_juices_df = pd.read_csv(fruit_and_fruit_juices_url, encoding="utf-8", header=None)
except UnicodeDecodeError:
    fruit_and_fruit_juices_df = pd.read_csv(fruit_and_fruit_juices_url, encoding="latin1", header=None)

fruit_and_fruit_juices_df.head()
# Out:
#                                                   0        1        2   \
# 0  Nutrient Value of Some Common Foods - 2008 Edi...      NaN      NaN
# 1                             FRUIT AND FRUIT JUICES      NaN      NaN
# 2                                          Food name  Measure  Weight
# 3                                                NaN      NaN        g
# 4                                              FRUIT      NaN      NaN
#
#        3       4        5             6            7                    8   \
# 0     NaN     NaN      NaN           NaN          NaN                  NaN
# 1     NaN     NaN      NaN           NaN          NaN                  NaN
# 2  Energy  Energy  Protein  Carbohydrate  Total Sugar  Total Dietary Fibre
# 3    kcal      kJ        g             g            g                    g
# 4     NaN     NaN      NaN           NaN          NaN                  NaN
#
#           9        10    11      12         13         14          15  \
# ...

# %%
fruit_and_fruit_juices_df = fruit_and_fruit_juices_df.iloc[2:].reset_index(drop=True)
fruit_and_fruit_juices_df.columns = fruit_and_fruit_juices_df.iloc[0]
fruit_and_fruit_juices_df = fruit_and_fruit_juices_df[1:].reset_index(drop=True)
fruit_and_fruit_juices_df.head()
# Out:
# 0                   Food name   Measure Weight  Energy Energy Protein  \
# 0                         NaN       NaN       g   kcal     kJ       g
# 1                       FRUIT       NaN     NaN    NaN    NaN     NaN
# 2  Apple with skin (7cm.diam)         1     138     72    300      tr
# 3     Applesauce, unsweetened     125mL     129     55    232      tr
# 4             Apricots, dried  6 halves      21     67    281       1
#
# 0 Carbohydrate Total Sugar Total Dietary Fibre Total Fat Calcium Iron Sodium  \
# 0            g           g                   g         g      mg   mg     mg
# 1          NaN         NaN                 NaN       NaN     NaN  NaN    NaN
# 2           19          14                 2.6        tr       8  0.2      1
# 3           15          13                 1.5        tr       4  0.2      3
# 4           17         NaN                 1.2        tr      13  1.3      3
#
# 0 Potassium Magnesium Phosphorus Vitamin A Beta carotene Lycopene Folate  \
# ...

# %%
fruit_and_fruit_juices_df.columns = [
    'Food Name', 'Measure', 'Weight (g)', 'Energy (kcal)', 'Energy (kJ)',
    'Protein (g)', 'Carbohydrate (g)', 'Total Sugar (g)',
    'Total Dietary Fibre (g)', 'Total Fat (g)', 'Calcium (mg)',
    'Iron (mg)', 'Sodium (mg)', 'Potassium (mg)', 'Magnesium (mg)',
    'Phosphorus (mg)', 'Vitamin A (RAE)', 'Beta-carotene (mcg)', 'Lycopene (mcg)',
    'Folate (DFE)', 'Vitamin C (mg)', 'Vitamin B12 (mcg)'
    ]

fruit_and_fruit_juices_df = fruit_and_fruit_juices_df.iloc[1:].reset_index(drop=True)

fruit_and_fruit_juices_df['Food Category'] = 'Fruit and Fruit Juices'
fruit_and_fruit_juices_df
# Out:
#                                             Food Name   Measure Weight (g)  \
# 0                                               FRUIT       NaN        NaN
# 1                          Apple with skin (7cm.diam)         1        138
# 2                             Applesauce, unsweetened     125mL        129
# 3                                     Apricots, dried  6 halves         21
# 4                                       Apricots, raw         3        105
# 5                                             Avocado      1/2         101
# 6                                              Banana         1        118
# 7                                        Blackberries     125mL         76
# 8                    Blueberries, frozen, unsweetened     125mL         82
# 9                                    Blueberries, raw     125mL         77
# 10                                    Cherries, sweet        10         68
# ...

# %%
fruit_and_fruit_juices_df.loc[1:54, 'Food Subcategory'] = "Fruit"
fruit_and_fruit_juices_df.loc[56:75, 'Food Subcategory'] = "Fruit Juices"

fruit_and_fruit_juices_df
# Out:
#                                             Food Name   Measure Weight (g)  \
# 0                                               FRUIT       NaN        NaN
# 1                          Apple with skin (7cm.diam)         1        138
# 2                             Applesauce, unsweetened     125mL        129
# 3                                     Apricots, dried  6 halves         21
# 4                                       Apricots, raw         3        105
# 5                                             Avocado      1/2         101
# 6                                              Banana         1        118
# 7                                        Blackberries     125mL         76
# 8                    Blueberries, frozen, unsweetened     125mL         82
# 9                                    Blueberries, raw     125mL         77
# 10                                    Cherries, sweet        10         68
# ...

# %%
fruit_and_fruit_juices_df = fruit_and_fruit_juices_df.drop(index=[0, 55])
fruit_and_fruit_juices_df = fruit_and_fruit_juices_df.reset_index(drop=True)
fruit_and_fruit_juices_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Food Name                74 non-null     object
#  1   Measure                  74 non-null     object
#  2   Weight (g)               74 non-null     object
#  3   Energy (kcal)            74 non-null     object
#  4   Energy (kJ)              74 non-null     object
#  5   Protein (g)              74 non-null     object
#  6   Carbohydrate (g)         74 non-null     object
#  7   Total Sugar (g)          69 non-null     object
#  8   Total Dietary Fibre (g)  73 non-null     object
#  9   Total Fat (g)            74 non-null     object
#  10  Calcium (mg)             74 non-null     object
#  11  Iron (mg)                74 non-null     object
#  12  Sodium (mg)              74 non-null     object
#  13  Potassium (mg)           74 non-null     object
# ...

# %%
dairy_foods_and_other_related_products_url = "https://raw.githubusercontent.com/yildiramdsa/nutrient_composition_of_common_foods_in_canada_analyzing_the_canadian_nutrient_file/main/data/raw/nutrient_value_dairy_foods_and_other_related_products_2008_valeur_nutritive_produits_laitiers_et_produits_annexes-eng.csv"

try:
    dairy_foods_and_other_related_products_df = pd.read_csv(dairy_foods_and_other_related_products_url, encoding="utf-8", header=None)
except UnicodeDecodeError:
    dairy_foods_and_other_related_products_df = pd.read_csv(dairy_foods_and_other_related_products_url, encoding="latin1", header=None)

dairy_foods_and_other_related_products_df.head()
# Out:
#                                                   0        1        2   \
# 0  Nutrient Value of Some Common Foods - 2008 Edi...      NaN      NaN
# 1             DAIRY FOODS AND OTHER RELATED PRODUCTS      NaN      NaN
# 2                                          Food name  Measure  Weight
# 3                                                NaN      NaN        g
# 4                               MILK AND SUBSTITUTES      NaN      NaN
#
#        3       4        5             6            7          8   \
# 0     NaN     NaN      NaN           NaN          NaN        NaN
# 1     NaN     NaN      NaN           NaN          NaN        NaN
# 2  Energy  Energy  Protein  Carbohydrate  Total Sugar  Total Fat
# 3    kcal      kJ        g             g            g          g
# 4     NaN     NaN      NaN           NaN          NaN        NaN
#
#               9            10       11    12      13         14         15  \
# ...

# %%
dairy_foods_and_other_related_products_nan_cols = dairy_foods_and_other_related_products_df.columns[dairy_foods_and_other_related_products_df.isna().all()].tolist()
dairy_foods_and_other_related_products_df = dairy_foods_and_other_related_products_df.drop(columns=dairy_foods_and_other_related_products_nan_cols)

# %%
dairy_foods_and_other_related_products_df = dairy_foods_and_other_related_products_df.iloc[2:].reset_index(drop=True)
dairy_foods_and_other_related_products_df.columns = dairy_foods_and_other_related_products_df.iloc[0]
dairy_foods_and_other_related_products_df = dairy_foods_and_other_related_products_df[1:].reset_index(drop=True)
dairy_foods_and_other_related_products_df.head()
# Out:
# 0                 Food name Measure Weight  Energy Energy Protein  \
# 0                       NaN     NaN       g   kcal     kJ       g
# 1      MILK AND SUBSTITUTES     NaN     NaN    NaN    NaN     NaN
# 2                Buttermilk   250mL     259    104    432       9
# 3  Milk, chocolate, 1% M.F.   250mL     264    166    695       9
# 4  Milk, chocolate, 2% M.F.   250mL     264    190    795       8
#
# 0 Carbohydrate Total Sugar Total Fat Saturated Fat Cholesterol Calcium Iron  \
# 0            g           g         g             g          mg      mg   mg
# 1          NaN         NaN       NaN           NaN         NaN     NaN  NaN
# 2           12          12         2           1.4          10     300  0.1
# 3           28          26         3           1.6           8     304  0.6
# 4           27          26         5           3.3          18     301  0.6
#
# 0 Sodium Potassium Magnesium Phosphorus Vitamin A Vitamin D Folate   \
# ...

# %%
dairy_foods_and_other_related_products_df.columns = [
    'Food Name', 'Measure', 'Weight (g)', 'Energy (kcal)', 'Energy (kJ)',
    'Protein (g)', 'Carbohydrate (g)', 'Total Sugar (g)', 'Total Fat (g)',
    'Saturated Fat (g)', 'Cholesterol (mg)', 'Calcium (mg)', 'Iron (mg)',
    'Sodium (mg)', 'Potassium (mg)', 'Magnesium (mg)', 'Phosphorus (mg)',
    'Vitamin A (RAE)', 'Vitamin D (mcg)', 'Folate (DFE)',
    'Vitamin B12 (mcg)', 'Riboflavin (mg)'
    ]

dairy_foods_and_other_related_products_df = dairy_foods_and_other_related_products_df.iloc[1:].reset_index(drop=True)

dairy_foods_and_other_related_products_df['Food Category'] = 'Dairy Foods and Other Related Products'
dairy_foods_and_other_related_products_df
# Out:
#                                             Food Name      Measure Weight (g)  \
# 0                                MILK AND SUBSTITUTES          NaN        NaN
# 1                                          Buttermilk        250mL        259
# 2                            Milk, chocolate, 1% M.F.        250mL        264
# 3                            Milk, chocolate, 2% M.F.        250mL        264
# 4                       Milk, partly skimmed, 1% M.F.        250mL        258
# 5                       Milk, partly skimmed, 2% M.F.        250mL        258
# 6   Milk, partly skimmed, 2% M.F., with added milk...        250mL        260
# 7                                          Milk, skim        250mL        259
# 8                              Milk, whole, 3.3% M.F.        250mL        258
# 9   Rice beverage, flavoured and unflavoured, enri...        250mL        259
# 10                  Soy beverage, chocolate, enriched        250mL        257
# ...

# %%
dairy_foods_and_other_related_products_df.loc[1:12, 'Food Subcategory'] = "Milk and Substitutes"
dairy_foods_and_other_related_products_df.loc[14:22, 'Food Subcategory'] = "Processed Milk"
dairy_foods_and_other_related_products_df.loc[24:33, 'Food Subcategory'] = "Milk Beverages"
dairy_foods_and_other_related_products_df.loc[35:44, 'Food Subcategory'] = "Yogourts and Fermented Milk Products"
dairy_foods_and_other_related_products_df.loc[46:71, 'Food Subcategory'] = "Cheese"
dairy_foods_and_other_related_products_df.loc[73:79, 'Food Subcategory'] = "Cream"
dairy_foods_and_other_related_products_df.loc[81:87, 'Food Subcategory'] = "Imitation Cream Products"
dairy_foods_and_other_related_products_df.loc[89:97, 'Food Subcategory'] = "Pudding"

dairy_foods_and_other_related_products_df
# Out:
#                                             Food Name      Measure Weight (g)  \
# 0                                MILK AND SUBSTITUTES          NaN        NaN
# 1                                          Buttermilk        250mL        259
# 2                            Milk, chocolate, 1% M.F.        250mL        264
# 3                            Milk, chocolate, 2% M.F.        250mL        264
# 4                       Milk, partly skimmed, 1% M.F.        250mL        258
# 5                       Milk, partly skimmed, 2% M.F.        250mL        258
# 6   Milk, partly skimmed, 2% M.F., with added milk...        250mL        260
# 7                                          Milk, skim        250mL        259
# 8                              Milk, whole, 3.3% M.F.        250mL        258
# 9   Rice beverage, flavoured and unflavoured, enri...        250mL        259
# 10                  Soy beverage, chocolate, enriched        250mL        257
# ...

# %%
dairy_foods_and_other_related_products_df = dairy_foods_and_other_related_products_df.drop(index=[0, 13, 23, 34, 45, 72, 80, 88])
dairy_foods_and_other_related_products_df = dairy_foods_and_other_related_products_df.reset_index(drop=True)
dairy_foods_and_other_related_products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Food Name          90 non-null     object
#  1   Measure            90 non-null     object
#  2   Weight (g)         90 non-null     object
#  3   Energy (kcal)      90 non-null     object
#  4   Energy (kJ)        90 non-null     object
#  5   Protein (g)        90 non-null     object
#  6   Carbohydrate (g)   90 non-null     object
#  7   Total Sugar (g)    84 non-null     object
#  8   Total Fat (g)      90 non-null     object
#  9   Saturated Fat (g)  90 non-null     object
#  10  Cholesterol (mg)   90 non-null     object
#  11  Calcium (mg)       90 non-null     object
#  12  Iron (mg)          90 non-null     object
#  13  Sodium (mg)        90 non-null     object
#  14  Potassium (mg)     90 non-null     object
#  15  Magnesium (mg)     90 non-null     object
# ...

# %%
eggs_and_egg_dishes_url = "https://raw.githubusercontent.com/yildiramdsa/nutrient_composition_of_common_foods_in_canada_analyzing_the_canadian_nutrient_file/main/data/raw/nutrient_value_eggs_and_egg_dishes_2008_valeur_nutritive_oeufs_et_plats_base_oeufs-eng.csv"

try:
    eggs_and_egg_dishes_df = pd.read_csv(eggs_and_egg_dishes_url, encoding="utf-8", header=None)
except UnicodeDecodeError:
    eggs_and_egg_dishes_df = pd.read_csv(eggs_and_egg_dishes_url, encoding="latin1", header=None)

eggs_and_egg_dishes_df.head()
# Out:
#                                                   0        1        2   \
# 0                                                NaN      NaN      NaN
# 1  Nutrient Value of Some Common Foods, 2008 Edition      NaN      NaN
# 2                                EGGS AND EGG DISHES      NaN      NaN
# 3                                          Food name  Measure  Weight
# 4                                                NaN      NaN        g
#
#        3       4        5             6          7              8   \
# 0     NaN     NaN      NaN           NaN        NaN            NaN
# 1     NaN     NaN      NaN           NaN        NaN            NaN
# 2     NaN     NaN      NaN           NaN        NaN            NaN
# 3  Energy  Energy  Protein  Carbohydrate  Total Fat  Saturated Fat
# 4    kcal      kJ        g             g          g              g
#
#                     9                    10           11       12    13  \
# ...

# %%
eggs_and_egg_dishes_df = eggs_and_egg_dishes_df.iloc[3:].reset_index(drop=True)
eggs_and_egg_dishes_df.columns = eggs_and_egg_dishes_df.iloc[0]
eggs_and_egg_dishes_df = eggs_and_egg_dishes_df[1:].reset_index(drop=True)
eggs_and_egg_dishes_df.head()
# Out:
# 0                                       Food name  Measure Weight  Energy  \
# 0                                             NaN      NaN       g   kcal
# 1  Egg substitute, frozen (yolk replaced), cooked   2 eggs     111    226
# 2                               Egg white, cooked  1 large      33     16
# 3                                Egg yolk, cooked  1 large      17     59
# 4                                      Egg, fried  2 large      92    173
#
# 0 Energy Protein Carbohydrate Total Fat Saturated Fat Monounsaturated Fat  \
# 0     kJ       g            g         g             g                   g
# 1    947      14            4        17           2.9                 4.6
# 2     66       3           tr         0             0                   0
# 3    249       3            1         6           1.7                 2.3
# 4    726      12            2        14           3.6                 5.8
#
# ...

# %%
eggs_and_egg_dishes_nan_cols = eggs_and_egg_dishes_df.columns[eggs_and_egg_dishes_df.isna().all()].tolist()
eggs_and_egg_dishes_df = eggs_and_egg_dishes_df.drop(columns=eggs_and_egg_dishes_nan_cols)
# Out:
# [nan, nan]

# %%
eggs_and_egg_dishes_df.columns = [
    'Food Name', 'Measure', 'Weight (g)', 'Energy (kcal)', 'Energy (kJ)',
    'Protein (g)', 'Carbohydrate (g)', 'Total Fat (g)', 'Saturated Fat (g)',
    'Monounsaturated Fat (g)',

    'Cholesterol (mg)', 'Calcium (mg)', 'Iron (mg)',
    'Sodium (mg)', 'Potassium (mg)', 'Magnesium (mg)', 'Phosphorus (mg)',
    'Vitamin A (RAE)', 'Vitamin D (mcg)', 'Folate (DFE)',
    'Vitamin B12 (mcg)', 'Riboflavin (mg)'
    ]

eggs_and_egg_dishes_df = eggs_and_egg_dishes_df.iloc[1:].reset_index(drop=True)

eggs_and_egg_dishes_df['Food Category'] = 'Eggs and Egg Dishes'
eggs_and_egg_dishes_df

# %%
fish_and_shellfish_url = "https://raw.githubusercontent.com/yildiramdsa/nutrient_composition_of_common_foods_in_canada_analyzing_the_canadian_nutrient_file/main/data/raw/nutrient_value_fish_and_shellfish_2008_valeur_nutritive_poissons_et_crustaces-eng.csv"

try:
    fish_and_shellfish_df = pd.read_csv(fish_and_shellfish_url, encoding="utf-8", header=None)
except UnicodeDecodeError:
    fish_and_shellfish_df = pd.read_csv(fish_and_shellfish_url, encoding="latin1", header=None)

fish_and_shellfish_df.head()
# Out:
#                                                   0        1        2   \
# 0  Nutrient Value of Some Common Foods, 2008 edition      NaN      NaN
# 1                                 FISH AND SHELLFISH      NaN      NaN
# 2                                          Food name  Measure  Weight
# 3                                                NaN      NaN        g
# 4                                               FISH      NaN      NaN
#
#        3       4        5             6          7              8   \
# 0     NaN     NaN      NaN           NaN        NaN            NaN
# 1     NaN     NaN      NaN           NaN        NaN            NaN
# 2  Energy  Energy  Protein  Carbohydrate  Total Fat  Saturated Fat
# 3    kcal      kJ        g             g          g              g
# 4     NaN     NaN      NaN           NaN        NaN            NaN
#
#                     9    10   11           12       13    14      15  \
# ...

# %%
fish_and_shellfish_df = fish_and_shellfish_df.iloc[2:].reset_index(drop=True)
fish_and_shellfish_df.columns = fish_and_shellfish_df.iloc[0]
fish_and_shellfish_df = fish_and_shellfish_df[1:].reset_index(drop=True)
fish_and_shellfish_df.head()
# Out:
# 0                                 Food name Measure Weight  Energy Energy  \
# 0                                       NaN     NaN       g   kcal     kJ
# 1                                      FISH     NaN     NaN    NaN    NaN
# 2  Anchovies, canned in oil, drained solids       2       8     17     70
# 3                       Arctic char, boiled     75g      75    119    496
# 4     Bass, mixed species, baked or broiled     75g      75    110    458
#
# 0 Protein Carbohydrate Total Fat Saturated Fat Polyunsaturated Fat   DHA  \
# 0       g            g         g             g                   g     g
# 1     NaN          NaN       NaN           NaN                 NaN   NaN
# 2       2            0         1           0.2                 0.2   0.1
# 3      20            0         4           0.7                 0.9   0.3
# 4      18            0         4           0.8                   1  0.34
#
# 0   EPA Cholesterol Calcium Iron Sodium Potassium Phosphorus Vitamin A  \
# ...

# %%
fish_and_shellfish_nan_cols = fish_and_shellfish_df.columns[fish_and_shellfish_df.isna().all()].tolist()
fish_and_shellfish_nan_cols
# Out:
# []

# %%
meat_and_poultry_url = "https://raw.githubusercontent.com/yildiramdsa/nutrient_composition_of_common_foods_in_canada_analyzing_the_canadian_nutrient_file/main/data/raw/nutrient_value_meat_and_poultry_2008_valeur_nutritive_2008_viande_et_volaille-eng.csv"

try:
    meat_and_poultry_df = pd.read_csv(meat_and_poultry_url, encoding="utf-8", header=None)
except UnicodeDecodeError:
    meat_and_poultry_df = pd.read_csv(meat_and_poultry_url, encoding="latin1", header=None)

meat_and_poultry_df.head()
# Out:
#                                                   0        1        2   \
# 0                                                NaN      NaN      NaN
# 1  Nutrient Value of Some Common Foods, 2008 edition      NaN      NaN
# 2                                   MEAT AND POULTRY      NaN      NaN
# 3                                          Food name  Measure  Weight
# 4                                                NaN      NaN        g
#
#        3       4        5             6          7              8   \
# 0     NaN     NaN      NaN           NaN        NaN            NaN
# 1     NaN     NaN      NaN           NaN        NaN            NaN
# 2     NaN     NaN      NaN           NaN        NaN            NaN
# 3  Energy  Energy  Protein  Carbohydrate  Total Fat  Saturated Fat
# 4    kcal      kJ        g             g          g              g
#
#                     9                    10           11    12      13  \
# ...

# %%
meat_and_poultry_df = meat_and_poultry_df.iloc[3:].reset_index(drop=True)
meat_and_poultry_df.columns = meat_and_poultry_df.iloc[0]
meat_and_poultry_df = meat_and_poultry_df[1:].reset_index(drop=True)
meat_and_poultry_df.head()
# Out:
# 0                             Food name Measure Weight  Energy Energy Protein  \
# 0                                   NaN     NaN       g   kcal     kJ       g
# 1                                  BEEF     NaN     NaN    NaN    NaN     NaN
# 2      Blade roast, lean + fat, braised     75g      75    200    834      26
# 3      Blade steak, lean + fat, braised     75g      75    227    947      23
# 4  Composite, roast, lean + fat, cooked     75g      75    181    756      24
#
# 0 Carbohydrate Total Fat Saturated Fat Monounsaturated Fat  \
# 0            g         g             g                   g
# 1          NaN       NaN           NaN                 NaN
# 2            0        10           4.0                 5.0
# 3            0        14           5.7                 7.1
# 4            0         8           3.5                 4.2
#
# 0 Polyunsaturated Fat Cholesterol Iron Sodium Potassium Magnesium Phosphorus  \
# ...

# %%
meat_and_poultry_nan_cols = meat_and_poultry_df.columns[meat_and_poultry_df.isna().all()].tolist()
meat_and_poultry_nan_cols
# Out:
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]

# %%
meat_and_poultry_df = meat_and_poultry_df.drop(columns=meat_and_poultry_nan_cols)
meat_and_poultry_df.head()
# Out:
# 0                             Food name Measure Weight  Energy Energy Protein  \
# 0                                   NaN     NaN       g   kcal     kJ       g
# 1                                  BEEF     NaN     NaN    NaN    NaN     NaN
# 2      Blade roast, lean + fat, braised     75g      75    200    834      26
# 3      Blade steak, lean + fat, braised     75g      75    227    947      23
# 4  Composite, roast, lean + fat, cooked     75g      75    181    756      24
#
# 0 Carbohydrate Total Fat Saturated Fat Monounsaturated Fat  \
# 0            g         g             g                   g
# 1          NaN       NaN           NaN                 NaN
# 2            0        10           4.0                 5.0
# 3            0        14           5.7                 7.1
# 4            0         8           3.5                 4.2
#
# 0 Polyunsaturated Fat Cholesterol Iron Sodium Potassium Magnesium Phosphorus  \
# ...

# %%
legumes_nuts_and_seeds_url = "https://raw.githubusercontent.com/yildiramdsa/nutrient_composition_of_common_foods_in_canada_analyzing_the_canadian_nutrient_file/main/data/raw/nutrient_value_legumes_nuts_and_seeds_2008_valeur_nutritive_legumineuses_noix_et_graines-eng.csv"

try:
    legumes_nuts_and_seeds_df = pd.read_csv(legumes_nuts_and_seeds_url, encoding="utf-8", header=None)
except UnicodeDecodeError:
    legumes_nuts_and_seeds_df = pd.read_csv(legumes_nuts_and_seeds_url, encoding="latin1", header=None)

legumes_nuts_and_seeds_df.head()
# Out:
#                                                   0        1        2   \
# 0                                                NaN      NaN      NaN
# 1  Nutrient Value of Some Common Foods, 2008 edition      NaN      NaN
# 2                            LEGUMES, NUTS AND SEEDS      NaN      NaN
# 3                                          Food name  Measure  Weight
# 4                                                NaN      NaN        g
#
#        3       4        5             6            7                     8   \
# 0     NaN     NaN      NaN           NaN          NaN                   NaN
# 1     NaN     NaN      NaN           NaN          NaN                   NaN
# 2     NaN     NaN      NaN           NaN          NaN                   NaN
# 3  Energy  Energy  Protein  Carbohydrate  Total Sugar  Total Daietary Fibre
# 4    kcal      kJ        g             g            g                     g
#
#           9              10                   11                   12  \
# ...

# %%
legumes_nuts_and_seeds_df = legumes_nuts_and_seeds_df.iloc[3:].reset_index(drop=True)
legumes_nuts_and_seeds_df.columns = legumes_nuts_and_seeds_df.iloc[0]
legumes_nuts_and_seeds_df = legumes_nuts_and_seeds_df[1:].reset_index(drop=True)
legumes_nuts_and_seeds_df.head()
# Out:
# 0                         Food name Measure Weight  Energy Energy Protein  \
# 0                               NaN     NaN       g   kcal     kJ       g
# 1                 MEATLESS PRODUCTS     NaN     NaN    NaN    NaN     NaN
# 2  Meatless breaded chicken nuggets       2      72    168    705      15
# 3              Meatless ground beef     75g      75    148    618      16
# 4                         Soy patty       1      70    136    568      15
#
# 0 Carbohydrate Total Sugar Total Daietary Fibre Total Fat Saturated Fat  \
# 0            g           g                    g         g             g
# 1          NaN         NaN                  NaN       NaN           NaN
# 2            6           0                  3.1         9           0.8
# 3            6           1                  3.5         7           1.1
# 4            5           1                  3.2         6           0.8
#
# 0 Monounsaturated Fat Polyunsaturated Fat Calcium Iron Sodium Potassium  \
# ...

# %%
legumes_nuts_and_seeds_nan_cols = legumes_nuts_and_seeds_df.columns[legumes_nuts_and_seeds_df.isna().all()].tolist()
legumes_nuts_and_seeds_nan_cols
# Out:
# [nan, nan]

# %%
legumes_nuts_and_seeds_df = legumes_nuts_and_seeds_df.drop(columns=legumes_nuts_and_seeds_nan_cols)
legumes_nuts_and_seeds_df.head()
# Out:
# 0                         Food name Measure Weight  Energy Energy Protein  \
# 0                               NaN     NaN       g   kcal     kJ       g
# 1                 MEATLESS PRODUCTS     NaN     NaN    NaN    NaN     NaN
# 2  Meatless breaded chicken nuggets       2      72    168    705      15
# 3              Meatless ground beef     75g      75    148    618      16
# 4                         Soy patty       1      70    136    568      15
#
# 0 Carbohydrate Total Sugar Total Daietary Fibre Total Fat Saturated Fat  \
# 0            g           g                    g         g             g
# 1          NaN         NaN                  NaN       NaN           NaN
# 2            6           0                  3.1         9           0.8
# 3            6           1                  3.5         7           1.1
# 4            5           1                  3.2         6           0.8
#
# 0 Monounsaturated Fat Polyunsaturated Fat Calcium Iron Sodium Potassium  \
# ...

# %%
fast_foods_url = "https://raw.githubusercontent.com/yildiramdsa/nutrient_composition_of_common_foods_in_canada_analyzing_the_canadian_nutrient_file/main/data/raw/nutrient_value_fast_foods_2008_valeur_nutritive_restaurant_minute-eng.csv"

try:
    fast_foods_df = pd.read_csv(fast_foods_url, encoding="utf-8", header=None)
except UnicodeDecodeError:
    fast_foods_df = pd.read_csv(fast_foods_url, encoding="latin1", header=None)

fast_foods_df.head()
# Out:
#                                                   0        1        2   \
# 0                                                NaN      NaN      NaN
# 1  Nutrient Value of Some Common Foods, 2008 edition      NaN      NaN
# 2                                         FAST FOODS      NaN      NaN
# 3                                          Food name  Measure  Weight
# 4                                                NaN      NaN        g
#
#        3       4        5             6            7                    8   \
# 0     NaN     NaN      NaN           NaN          NaN                  NaN
# 1     NaN     NaN      NaN           NaN          NaN                  NaN
# 2     NaN     NaN      NaN           NaN          NaN                  NaN
# 3  Energy  Energy  Protein  Carbohydrate  Total Sugar  Total Dietary Fibre
# 4    kcal      kJ        g             g            g                    g
#
#           9              10           11       12    13      14         15  \
# ...

# %%
fast_foods_df = fast_foods_df.iloc[3:].reset_index(drop=True)
fast_foods_df.columns = fast_foods_df.iloc[0]
fast_foods_df = fast_foods_df[1:].reset_index(drop=True)
fast_foods_df.head()
# Out:
# 0              Food name Measure Weight  Energy Energy Protein Carbohydrate  \
# 0                    NaN     NaN       g   kcal     kJ       g            g
# 1              BEVERAGES     NaN     NaN    NaN    NaN     NaN          NaN
# 2  Milk shake, chocolate   250mL     175    223    931       6           36
# 3    Milk shake, vanilla   250mL     175    195    814       6           31
# 4            SIDE DISHES     NaN     NaN    NaN    NaN     NaN          NaN
#
# 0 Total Sugar Total Dietary Fibre Total Fat Saturated Fat Cholesterol Calcium  \
# 0           g                   g         g             g          mg      mg
# 1         NaN                 NaN       NaN           NaN         NaN     NaN
# 2          33                 3.3         6           4.1          23     198
# 3          31                 0.2         5           3.3          19     214
# 4         NaN                 NaN       NaN           NaN         NaN     NaN
#
# ...

# %%
fast_foods_nan_cols = fast_foods_df.columns[fast_foods_df.isna().all()].tolist()
fast_foods_nan_cols
# Out:
# [nan, nan]

# %%
fast_foods_df = fast_foods_df.drop(columns=fast_foods_nan_cols)
fast_foods_df.head()
# Out:
# 0              Food name Measure Weight  Energy Energy Protein Carbohydrate  \
# 0                    NaN     NaN       g   kcal     kJ       g            g
# 1              BEVERAGES     NaN     NaN    NaN    NaN     NaN          NaN
# 2  Milk shake, chocolate   250mL     175    223    931       6           36
# 3    Milk shake, vanilla   250mL     175    195    814       6           31
# 4            SIDE DISHES     NaN     NaN    NaN    NaN     NaN          NaN
#
# 0 Total Sugar Total Dietary Fibre Total Fat Saturated Fat Cholesterol Calcium  \
# 0           g                   g         g             g          mg      mg
# 1         NaN                 NaN       NaN           NaN         NaN     NaN
# 2          33                 3.3         6           4.1          23     198
# 3          31                 0.2         5           3.3          19     214
# 4         NaN                 NaN       NaN           NaN         NaN     NaN
#
# ...

# %%
mixed_dishes_url = "https://raw.githubusercontent.com/yildiramdsa/nutrient_composition_of_common_foods_in_canada_analyzing_the_canadian_nutrient_file/main/data/raw/nutrient_value_mixed_dishes_2008_valeur_nutritive_mets_composes-eng.csv"

try:
    mixed_dishes_df = pd.read_csv(mixed_dishes_url, encoding="utf-8", header=None)
except UnicodeDecodeError:
    mixed_dishes_df = pd.read_csv(mixed_dishes_url, encoding="latin1", header=None)

mixed_dishes_df.head()
# Out:
#                                                   0        1        2   \
# 0                                                NaN      NaN      NaN
# 1  Nutrient Value of Some Common Foods, 2008 edition      NaN      NaN
# 2                                       MIXED DISHES      NaN      NaN
# 3                                          Food name  Measure  Weight
# 4                                                NaN      NaN        g
#
#        3       4       5             6            7                    8   \
# 0     NaN     NaN     NaN           NaN          NaN                  NaN
# 1     NaN     NaN     NaN           NaN          NaN                  NaN
# 2     NaN     NaN     NaN           NaN          NaN                  NaN
# 3  Energy  Energy  Protei  Carbohydrate  Total Sugar  Total Dietary Fibre
# 4    kcal      kJ       g             g            g                    g
#
#           9              10           11       12    13      14         15  \
# ...

# %%
mixed_dishes_df = mixed_dishes_df.iloc[3:].reset_index(drop=True)
mixed_dishes_df.columns = mixed_dishes_df.iloc[0]
mixed_dishes_df = mixed_dishes_df[1:].reset_index(drop=True)
mixed_dishes_df.head()
# Out:
# 0                             Food name       Measure Weight  Energy Energy  \
# 0                                   NaN           NaN       g   kcal     kJ
# 1                               MEXICAN           NaN     NaN    NaN    NaN
# 2         Burrito with beans and cheese             1      93    189    790
# 3  Burrito with beef, cheese and chilli             1     152    316   1322
# 4                    Nachos with cheese  15-20 nachos     113    346   1446
#
# 0 Protei Carbohydrate Total Sugar Total Dietary Fibre Total Fat Saturated Fat  \
# 0      g            g           g                   g         g             g
# 1    NaN          NaN         NaN                 NaN       NaN           NaN
# 2      8           27         NaN                 3.8         6           3.4
# 3     20           32         NaN                 2.2        12           5.2
# 4      9           36         NaN                 4.1        19           7.8
#
# ...

# %%
mixed_dishes_nan_cols = mixed_dishes_df.columns[mixed_dishes_df.isna().all()].tolist()
mixed_dishes_nan_cols
# Out:
# [nan, nan, nan, nan, nan, nan, nan, nan]

# %%
mixed_dishes_df = mixed_dishes_df.drop(columns=mixed_dishes_nan_cols)
mixed_dishes_df.head()
# Out:
# 0                             Food name       Measure Weight  Energy Energy  \
# 0                                   NaN           NaN       g   kcal     kJ
# 1                               MEXICAN           NaN     NaN    NaN    NaN
# 2         Burrito with beans and cheese             1      93    189    790
# 3  Burrito with beef, cheese and chilli             1     152    316   1322
# 4                    Nachos with cheese  15-20 nachos     113    346   1446
#
# 0 Protei Carbohydrate Total Sugar Total Dietary Fibre Total Fat Saturated Fat  \
# 0      g            g           g                   g         g             g
# 1    NaN          NaN         NaN                 NaN       NaN           NaN
# 2      8           27         NaN                 3.8         6           3.4
# 3     20           32         NaN                 2.2        12           5.2
# 4      9           36         NaN                 4.1        19           7.8
#
# ...

# %%
soups_url = "https://raw.githubusercontent.com/yildiramdsa/nutrient_composition_of_common_foods_in_canada_analyzing_the_canadian_nutrient_file/main/data/raw/nutrient_value_some_common_foods_soups-2008-valeur_nutritive_quelques_aliments_usuels_soupe-eng.csv"

try:
    soups_df = pd.read_csv(soups_url, encoding="utf-8", header=None)
except UnicodeDecodeError:
    soups_df = pd.read_csv(soups_url, encoding="latin1", header=None)

soups_df.head()
# Out:
#                                                   0        1        2   \
# 0                                                NaN      NaN      NaN
# 1  Nutrient Value of Some Common Foods, 2008 edition      NaN      NaN
# 2                                              SOUPS      NaN      NaN
# 3                                          Food name  Measure  Weight
# 4                                                NaN      NaN        g
#
#        3       4        5             6            7                    8   \
# 0     NaN     NaN      NaN           NaN          NaN                  NaN
# 1     NaN     NaN      NaN           NaN          NaN                  NaN
# 2     NaN     NaN      NaN           NaN          NaN                  NaN
# 3  Energy  Energy  Protein  Carbohydrate  Total Sugar  Total Dietary Fibre
# 4    kcal      kJ        g             g            g                    g
#
#           9              10           11       12    13      14         15  \
# ...

# %%
soups_df = soups_df.iloc[3:].reset_index(drop=True)
soups_df.columns = soups_df.iloc[0]
soups_df = soups_df[1:].reset_index(drop=True)
soups_df.head()
# Out:
# 0                        Food name Measure Weight  Energy Energy Protein  \
# 0                              NaN     NaN       g   kcal     kJ       g
# 1                   READY-TO-SERVE     NaN     NaN    NaN    NaN     NaN
# 2  Beef or chicken, broth/bouillon   250mL     254     18     74       3
# 3                     Beef, chunky   250mL     254    180    753      12
# 4           Chicken noodle, chunky   250mL     254    185    773      13
#
# 0 Carbohydrate Total Sugar Total Dietary Fibre Total Fat Saturated Fat  \
# 0            g           g                   g         g             g
# 1          NaN         NaN                 NaN       NaN           NaN
# 2           tr           0                   0         1           0.3
# 3           21           2                 1.5         5           2.7
# 4           18           2                 4.1         6           1.5
#
# 0 Cholesterol Calcium Iron Sodium Potassium Magnesium Phosphorus Vitamin A  \
# ...

# %%
soups_nan_cols = soups_df.columns[soups_df.isna().all()].tolist()
soups_nan_cols
# Out:
# [nan, nan]

# %%
soups_df = soups_df.drop(columns=soups_nan_cols)
soups_df.head()
# Out:
# 0                        Food name Measure Weight  Energy Energy Protein  \
# 0                              NaN     NaN       g   kcal     kJ       g
# 1                   READY-TO-SERVE     NaN     NaN    NaN    NaN     NaN
# 2  Beef or chicken, broth/bouillon   250mL     254     18     74       3
# 3                     Beef, chunky   250mL     254    180    753      12
# 4           Chicken noodle, chunky   250mL     254    185    773      13
#
# 0 Carbohydrate Total Sugar Total Dietary Fibre Total Fat Saturated Fat  \
# 0            g           g                   g         g             g
# 1          NaN         NaN                 NaN       NaN           NaN
# 2           tr           0                   0         1           0.3
# 3           21           2                 1.5         5           2.7
# 4           18           2                 4.1         6           1.5
#
# 0 Cholesterol Calcium Iron Sodium Potassium Magnesium Phosphorus Vitamin A  \
# ...

# %%
fats_and_oils_url = "https://raw.githubusercontent.com/yildiramdsa/nutrient_composition_of_common_foods_in_canada_analyzing_the_canadian_nutrient_file/main/data/raw/nutrient_value_fats_and_oils_foods_2008_valeur_nutritive_matieres_grasses_et_huiles-eng.csv"

try:
    fats_and_oils_df = pd.read_csv(fats_and_oils_url, encoding="utf-8", header=None)
except UnicodeDecodeError:
    fats_and_oils_df = pd.read_csv(fats_and_oils_url, encoding="latin1", header=None)

fats_and_oils_df.head()
# Out:
#                                                   0        1        2   \
# 0                                                NaN      NaN      NaN
# 1  Nutrient Value of Some Common Foods, 2008 Edition      NaN      NaN
# 2                                      FATS AND OILS      NaN      NaN
# 3                                          Food name  Measure  Weight
# 4                                                NaN      NaN        g
#
#        3       4        5             6          7              8   \
# 0     NaN     NaN      NaN           NaN        NaN            NaN
# 1     NaN     NaN      NaN           NaN        NaN            NaN
# 2     NaN     NaN      NaN           NaN        NaN            NaN
# 3  Energy  Energy  Protein  Carbohydrate  Total Fat  Saturated Fat
# 4    kcal      kJ        g             g          g              g
#
#                     9                    10         11           12       13  \
# ...

# %%
fats_and_oils_df = fats_and_oils_df.iloc[3:].reset_index(drop=True)
fats_and_oils_df.columns = fats_and_oils_df.iloc[0]
fats_and_oils_df = fats_and_oils_df[1:].reset_index(drop=True)
fats_and_oils_df.head()
# Out:
# 0                                          Food name Measure Weight  Energy  \
# 0                                                NaN     NaN       g   kcal
# 1                               BUTTER AND MARGARINE     NaN     NaN    NaN
# 2  Becel, tub, calorie-reduced, canola and safflo...     5mL       5     17
# 3  Becel, tub, canola and safflower oils (non-hyd...     5mL       5     34
# 4                                             Butter     5mL       5     34
#
# 0 Energy Protein Carbohydrate Total Fat Saturated Fat Monounsaturated Fat  \
# 0     kJ       g            g         g             g                   g
# 1    NaN     NaN          NaN       NaN           NaN                 NaN
# 2     70      tr           tr         2           0.3                 0.8
# 3    144      tr           tr         4           0.5                 1.7
# 4    144      tr           tr         4           2.5                 1.0
#
# ...

# %%
fats_and_oils_nan_cols = fats_and_oils_df.columns[fats_and_oils_df.isna().all()].tolist()
fats_and_oils_nan_cols
# Out:
# [nan, nan]

# %%
fats_and_oils_df = fats_and_oils_df.drop(columns=fats_and_oils_nan_cols)
fats_and_oils_df.head()
# Out:
# 0                                          Food name Measure Weight  Energy  \
# 0                                                NaN     NaN       g   kcal
# 1                               BUTTER AND MARGARINE     NaN     NaN    NaN
# 2  Becel, tub, calorie-reduced, canola and safflo...     5mL       5     17
# 3  Becel, tub, canola and safflower oils (non-hyd...     5mL       5     34
# 4                                             Butter     5mL       5     34
#
# 0 Energy Protein Carbohydrate Total Fat Saturated Fat Monounsaturated Fat  \
# 0     kJ       g            g         g             g                   g
# 1    NaN     NaN          NaN       NaN           NaN                 NaN
# 2     70      tr           tr         2           0.3                 0.8
# 3    144      tr           tr         4           0.5                 1.7
# 4    144      tr           tr         4           2.5                 1.0
#
# ...

# %%
sweets_and_sugars_url = "https://raw.githubusercontent.com/yildiramdsa/nutrient_composition_of_common_foods_in_canada_analyzing_the_canadian_nutrient_file/main/data/raw/nutrient_value_some_common_foods_sweets_sugars-2008-valeur_nutritive_quelques_aliments_usuels_sucres_sucreries-eng.csv"

try:
    sweets_and_sugars_df = pd.read_csv(sweets_and_sugars_url, encoding="utf-8", header=None)
except UnicodeDecodeError:
    sweets_and_sugars_df = pd.read_csv(sweets_and_sugars_url, encoding="latin1", header=None)

sweets_and_sugars_df.head()
# Out:
#                                                   0        1        2   \
# 0                                                NaN      NaN      NaN
# 1  Nutrient Value of Some Common Foods, 2008 Edition      NaN      NaN
# 2                                  SWEETS AND SUGARS      NaN      NaN
# 3                                          Food name  Measure  Weight
# 4                                                NaN      NaN        g
#
#        3       4        5             6            7                    8   \
# 0     NaN     NaN      NaN           NaN          NaN                  NaN
# 1     NaN     NaN      NaN           NaN          NaN                  NaN
# 2     NaN     NaN      NaN           NaN          NaN                  NaN
# 3  Energy  Energy  Protein  Carbohydrate  Total Sugar  Total Dietary Fibre
# 4    kcal      kJ        g             g            g                    g
#
#           9              10           11       12    13      14         15  \
# ...

# %%
sweets_and_sugars_df = sweets_and_sugars_df.iloc[3:].reset_index(drop=True)
sweets_and_sugars_df.columns = sweets_and_sugars_df.iloc[0]
sweets_and_sugars_df = sweets_and_sugars_df[1:].reset_index(drop=True)
sweets_and_sugars_df.head()
# Out:
# 0                       Food name Measure Weight  Energy Energy Protein  \
# 0                             NaN     NaN       g   kcal     kJ       g
# 1  SUGAR, HONEY AND SUBSTITUTIONS     NaN     NaN    NaN    NaN     NaN
# 2                     Brown sugar     5mL       5     18     73       0
# 3                           Honey     5mL       7     22     91      tr
# 4          Icing sugar (powdered)     5mL       3     10     41       0
#
# 0 Carbohydrate Total Sugar Total Dietary Fibre Total Fat Saturated Fat  \
# 0            g           g                   g         g             g
# 1          NaN         NaN                 NaN       NaN           NaN
# 2            5           4                   0         0             0
# 3            6           6                  tr         0             0
# 4            2           2                   0        tr             0
#
# 0 Cholesterol Calcium Iron Sodium Potassium Magnesium Phosphorus Vitamin A  \
# ...

# %%
sweets_and_sugars_nan_cols = sweets_and_sugars_df.columns[sweets_and_sugars_df.isna().all()].tolist()
sweets_and_sugars_nan_cols
# Out:
# [nan, nan]

# %%
sweets_and_sugars_df = sweets_and_sugars_df.drop(columns=sweets_and_sugars_nan_cols)
sweets_and_sugars_df.head()
# Out:
# 0                       Food name Measure Weight  Energy Energy Protein  \
# 0                             NaN     NaN       g   kcal     kJ       g
# 1  SUGAR, HONEY AND SUBSTITUTIONS     NaN     NaN    NaN    NaN     NaN
# 2                     Brown sugar     5mL       5     18     73       0
# 3                           Honey     5mL       7     22     91      tr
# 4          Icing sugar (powdered)     5mL       3     10     41       0
#
# 0 Carbohydrate Total Sugar Total Dietary Fibre Total Fat Saturated Fat  \
# 0            g           g                   g         g             g
# 1          NaN         NaN                 NaN       NaN           NaN
# 2            5           4                   0         0             0
# 3            6           6                  tr         0             0
# 4            2           2                   0        tr             0
#
# 0 Cholesterol Calcium Iron Sodium Potassium Magnesium Phosphorus Vitamin A  \
# ...

# %%
snacks_url = "https://raw.githubusercontent.com/yildiramdsa/nutrient_composition_of_common_foods_in_canada_analyzing_the_canadian_nutrient_file/main/data/raw/nutrient_value_snacks_2008_valeur_nutritive_grignotises-eng.csv"

try:
    snacks_df = pd.read_csv(snacks_url, encoding="utf-8", header=None)
except UnicodeDecodeError:
    snacks_df = pd.read_csv(snacks_url, encoding="latin1", header=None)

snacks_df.head()
# Out:
#                                                   0        1        2   \
# 0                                                NaN      NaN      NaN
# 1  Nutrient Value of Some Common Foods, 2008 Edition      NaN      NaN
# 2                                             SNACKS      NaN      NaN
# 3                                          Food name  Measure  Weight
# 4                                                NaN      NaN        g
#
#        3       4        5             6            7                    8   \
# 0     NaN     NaN      NaN           NaN          NaN                  NaN
# 1     NaN     NaN      NaN           NaN          NaN                  NaN
# 2     NaN     NaN      NaN           NaN          NaN                  NaN
# 3  Energy  Energy  Protein  Carbohydrate  Total Sugar  Total Dietary Fibre
# 4    kcal      kJ        g             g            g                    g
#
#           9              10           11       12    13      14         15  \
# ...

# %%
snacks_df = snacks_df.iloc[3:].reset_index(drop=True)
snacks_df.columns = snacks_df.iloc[0]
snacks_df = snacks_df[1:].reset_index(drop=True)
snacks_df.head()
# Out:
# 0                            Food name Measure Weight  Energy Energy Protein  \
# 0                                  NaN     NaN       g   kcal     kJ       g
# 1                              POPCORN     NaN     NaN    NaN    NaN     NaN
# 2                           Air-popped   250mL       8     32    135       1
# 3                       Caramel-coated   250mL      37    160    670       1
# 4  Microwave, low fat and reduced salt   250mL       8     34    144       1
#
# 0 Carbohydrate Total Sugar Total Dietary Fibre Total Fat Saturated Fat  \
# 0            g           g                   g         g             g
# 1          NaN         NaN                 NaN       NaN           NaN
# 2            7          tr                 1.3        tr            tr
# 3           29          20                 1.9         5           1.3
# 4            6          tr                 1.1         1           0.1
#
# ...

# %%
snacks_nan_cols = snacks_df.columns[snacks_df.isna().all()].tolist()
snacks_nan_cols
# Out:
# [nan, nan]

# %%
snacks_df = snacks_df.drop(columns=snacks_nan_cols)
snacks_df.head()
# Out:
# 0                            Food name Measure Weight  Energy Energy Protein  \
# 0                                  NaN     NaN       g   kcal     kJ       g
# 1                              POPCORN     NaN     NaN    NaN    NaN     NaN
# 2                           Air-popped   250mL       8     32    135       1
# 3                       Caramel-coated   250mL      37    160    670       1
# 4  Microwave, low fat and reduced salt   250mL       8     34    144       1
#
# 0 Carbohydrate Total Sugar Total Dietary Fibre Total Fat Saturated Fat  \
# 0            g           g                   g         g             g
# 1          NaN         NaN                 NaN       NaN           NaN
# 2            7          tr                 1.3        tr            tr
# 3           29          20                 1.9         5           1.3
# 4            6          tr                 1.1         1           0.1
#
# ...

# %%
beverages_url = "https://raw.githubusercontent.com/yildiramdsa/nutrient_composition_of_common_foods_in_canada_analyzing_the_canadian_nutrient_file/main/data/raw/nutrient_value_beverages_2008_valeur_nutritive_boissons-eng.csv"

try:
    beverages_df = pd.read_csv(beverages_url, encoding="utf-8", header=None)
except UnicodeDecodeError:
    beverages_df = pd.read_csv(beverages_url, encoding="latin1", header=None)

beverages_df.head()
# Out:
#                                                   0        1        2   \
# 0                                                NaN      NaN      NaN
# 1  Nutrient Value of Some Common Foods, 2008 Edition      NaN      NaN
# 2                                          BEVERAGES      NaN      NaN
# 3                                          Food name  Measure  Weight
# 4                                                NaN                 g
#
#        3       4        5             6            7                    8   \
# 0     NaN     NaN      NaN           NaN          NaN                  NaN
# 1     NaN     NaN      NaN           NaN          NaN                  NaN
# 2     NaN     NaN      NaN           NaN          NaN                  NaN
# 3  Energy  Energy  Protein  Carbohydrate  Total Sugar  Total Dietary Fibre
# 4    kcal      kJ        g             g            g                    g
#
#           9              10           11       12    13      14         15  \
# ...

# %%
beverages_df = beverages_df.iloc[3:].reset_index(drop=True)
beverages_df.columns = beverages_df.iloc[0]
beverages_df = beverages_df[1:].reset_index(drop=True)
beverages_df.head()
# Out:
# 0                      Food name Measure Weight  Energy Energy Protein  \
# 0                            NaN               g   kcal     kJ       g
# 1     COFFEE, TEA AND SUSTITUTES     NaN     NaN    NaN    NaN     NaN
# 2                    Chai, latte   250mL     242    149    624       5
# 3                 Coffee, brewed   250mL     250    2.5   10.0      tr
# 4  Coffee, brewed, decaffeinated   250mL     251    2.5   10.0      tr
#
# 0 Carbohydrate Total Sugar Total Dietary Fibre Total Fat Saturated Fat  \
# 0            g           g                   g         g             g
# 1          NaN         NaN                 NaN       NaN           NaN
# 2           26          26                   0         3           2.0
# 3            0           0                   0        tr            tr
# 4            0           0                   0         0             0
#
# 0 Cholesterol Calcium Iron Sodium Potassium Magnesium Phosphorus Vitamin A  \
# ...

# %%
beverages_nan_cols = beverages_df.columns[beverages_df.isna().all()].tolist()
beverages_nan_cols
# Out:
# [nan, nan]

# %%
beverages_df = beverages_df.drop(columns=beverages_nan_cols)
beverages_df.head()
# Out:
# 0                      Food name Measure Weight  Energy Energy Protein  \
# 0                            NaN               g   kcal     kJ       g
# 1     COFFEE, TEA AND SUSTITUTES     NaN     NaN    NaN    NaN     NaN
# 2                    Chai, latte   250mL     242    149    624       5
# 3                 Coffee, brewed   250mL     250    2.5   10.0      tr
# 4  Coffee, brewed, decaffeinated   250mL     251    2.5   10.0      tr
#
# 0 Carbohydrate Total Sugar Total Dietary Fibre Total Fat Saturated Fat  \
# 0            g           g                   g         g             g
# 1          NaN         NaN                 NaN       NaN           NaN
# 2           26          26                   0         3           2.0
# 3            0           0                   0        tr            tr
# 4            0           0                   0         0             0
#
# 0 Cholesterol Calcium Iron Sodium Potassium Magnesium Phosphorus Vitamin A  \
# ...

# %%
miscellaneous_url = "https://raw.githubusercontent.com/yildiramdsa/nutrient_composition_of_common_foods_in_canada_analyzing_the_canadian_nutrient_file/main/data/raw/nutrient_value_miscellaneous_foods_2008_valeur_nutritive_divers-eng.csv"

try:
    miscellaneous_df = pd.read_csv(miscellaneous_url, encoding="utf-8", header=None)
except UnicodeDecodeError:
    miscellaneous_df = pd.read_csv(miscellaneous_url, encoding="latin1", header=None)

miscellaneous_df.head()
# Out:
#                                                   0        1        2   \
# 0                                                NaN      NaN      NaN
# 1  Nutrient Value of Some Common Foods, 2008 Edition      NaN      NaN
# 2                                MISCELLANEOUS FOODS      NaN      NaN
# 3                                          Food name  Measure  Weight
# 4                                                NaN      NaN        g
#
#        3       4        5             6            7          8   \
# 0     NaN     NaN      NaN           NaN          NaN        NaN
# 1     NaN     NaN      NaN           NaN          NaN        NaN
# 2     NaN     NaN      NaN           NaN          NaN        NaN
# 3  Energy  Energy  Protein  Carbohydrate  Total Sugar  Total Fat
# 4    kcal      kJ        g             g            g          g
#
#               9                    10                   11           12  \
# 0            NaN                  NaN                  NaN          NaN
# ...

# %%
miscellaneous_df = miscellaneous_df.iloc[3:].reset_index(drop=True)
miscellaneous_df.columns = miscellaneous_df.iloc[0]
miscellaneous_df = miscellaneous_df[1:].reset_index(drop=True)
miscellaneous_df.head()
# Out:
# 0                   Food name Measure Weight  Energy Energy Protein  \
# 0                         NaN     NaN       g   kcal     kJ       g
# 1                  CONDIMENTS     NaN     NaN    NaN    NaN     NaN
# 2  Bacon bits, simulated meat    15mL       7     34    141       2
# 3                     Ketchup    15mL      15     15     64      tr
# 4                     Mustard    15mL      16     11     44       1
#
# 0 Carbohydrate Total Sugar Total Fat Saturated Fat Monounsaturated Fat  \
# 0            g           g         g             g                   g
# 1          NaN         NaN       NaN           NaN                 NaN
# 2            2           0         2           0.3                 0.4
# 3            4           3        tr            tr                  tr
# 4            1          tr         1            tr                 0.4
#
# 0 Polyunsaturated Fat Cholesterol Calcium Iron Sodium Potassium Magnesium  \
# ...

# %%
miscellaneous_nan_cols = miscellaneous_df.columns[miscellaneous_df.isna().all()].tolist()
miscellaneous_nan_cols
# Out:
# [nan, nan]

# %%
miscellaneous_df = miscellaneous_df.drop(columns=miscellaneous_nan_cols)
miscellaneous_df.head()
# Out:
# 0                   Food name Measure Weight  Energy Energy Protein  \
# 0                         NaN     NaN       g   kcal     kJ       g
# 1                  CONDIMENTS     NaN     NaN    NaN    NaN     NaN
# 2  Bacon bits, simulated meat    15mL       7     34    141       2
# 3                     Ketchup    15mL      15     15     64      tr
# 4                     Mustard    15mL      16     11     44       1
#
# 0 Carbohydrate Total Sugar Total Fat Saturated Fat Monounsaturated Fat  \
# 0            g           g         g             g                   g
# 1          NaN         NaN       NaN           NaN                 NaN
# 2            2           0         2           0.3                 0.4
# 3            4           3        tr            tr                  tr
# 4            1          tr         1            tr                 0.4
#
# 0 Polyunsaturated Fat Cholesterol Calcium Iron Sodium Potassium Magnesium  \
# ...
